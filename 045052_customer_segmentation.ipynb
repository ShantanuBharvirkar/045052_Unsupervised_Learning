# %% [markdown]
# **Name:** **Shantanu Bharvirkar**
#
# **Roll No.** **045052**

# %% [markdown]
# **1. Project Objectives | Problem Statements**
#
# **1.1. PO1 | PS1: Segmentation of Consumer Data using Unsupervised Machine Learning Clustering Algorithms**
#
#    - **Objective:** To segment consumer data into distinct groups or clusters using unsupervised machine learning clustering algorithms.
#    - **Problem Statement:** Develop a methodology to effectively segment consumer data to uncover underlying patterns and groupings without prior labeled information.
#
# **1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters**
#
#    - **Objective:** Determine the optimal number of segments or clusters within the consumer data.
#    - **Problem Statement:** Establish a technique to identify the most suitable number of clusters that best represent the inherent structure of the data, considering both internal cohesion and external separation metrics.
#
# **1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics**
#
#    - **Objective:** Extract meaningful characteristics or features associated with each identified segment or cluster.
#    - **Problem Statement:** Develop methodologies to interpret and describe the distinguishing characteristics of each cluster, enabling actionable insights for marketing and business strategies.
# Sure, here's how you can structure the "Description of Data" section of your report in the requested format:
#
# ---
#
# **2. Description of Data**
#
# **2.1. Data Source, Size, Shape**
#
#    **2.1.1. Data Source (Website Link)**
#
#    - The data was sourced from an internal database provided by [Name of the Company/Organization].
#
#    **2.1.2. Data Size (in KB | MB | GB …)**
#
#    - The size of the dataset is approximately 4.67 MB.
#
#    **2.1.3. Data Shape (Dimension: Number of Variables | Number of Records)**
#
#    - The dataset comprises **50,000 records and 6 variable**s**.
#
# --
# 2.2. Description** of Variables
# **
# 2.2.1. Index Variable(s):
# •	CustomerID
# 2.2.2.1. Variables or Features having Nominal Categories | Categor**ical Varia**bles or Features - Nominal Type:
# •	Gender
# 2**.2.3. Non-Categorical Variables or Features:
# •	Age
#
# **3.2. Data Analysis**
#
# **3.2.1.1. PO1 | PS1:: Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance**
#
# The base model employed K-Means clustering with the Euclidean distance metric, a commonly used unsupervised learning algorithm for partitioning data into distinct clusters. This method iteratively assigns data points to clusters based on minimizing the Euclidean distance between data points and cluster centroids. K-Means is chosen for its simplicity, efficiency, and effectiveness in handling large datasets.
#
# **3.2.1.2. PO1 | PS1:: Unsupervised Machine Learning Clustering Algorithms: {DBSCAN | BIRCH | OPTICS} (Comparison Models: At Least One) | Metrics Used - Euclidean Distance**
#
# In addition to K-Means, alternative clustering algorithms such as DBSCAN, BIRCH, and OPTICS were explored, utilizing the Euclidean distance metric. DBSCAN (Density-Based Spatial Clustering of Applications with Noise), BIRCH (Balanced Iterative Reducing and Clustering using Hierarchies), and OPTICS (Ordering Points To Identify the Clustering Structure) offer different approaches to clustering, addressing specific challenges such as noise, density, and scalability. Comparing these algorithms provides insights into their suitability for the dataset and problem at hand.
#
# **3.2.2.1.1. PO2 | PS2:: Clustering Model Performance Evaluation: Silhouette Score | Davies-Bouldin Score (Base Model: K-Means)**
#
# Evaluation of the K-Means base model's performance was conducted using Silhouette Score and Davies-Bouldin Score. The Silhouette Score measures the compactness and separation of clusters, with higher values indicating better-defined clusters. Meanwhile, the Davies-Bouldin Score assesses cluster separation and cohesion, with lower scores indicating better clustering. These metrics provide quantitative assessments of clustering quality, aiding in the selection of the optimal number of clusters and algorithm tuning.
#
# **3.2.2.1.2. PO2 | PS2:: Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Means)**
#
# Time statistics and memory usage (CPU/GPU) were analyzed to evaluate the computational efficiency of the K-Means base model. Efficient memory utilization and processing time are crucial for scalability and practical implementation of clustering algorithms, especially for large datasets. Understanding the computational requirements allows for informed decision-making regarding hardware resources and algorithm selection.
#
# **3.2.2.2.1. PO2 | PS2:: Clustering Model Performance Evaluation: Silhouette Score | Davies-Bouldin Score (Comparison Models: DBSCAN | BIRCH | OPTICS - At Least One)**
#
# Similar performance evaluation metrics were applied to the comparison models (DBSCAN, BIRCH, OPTICS) to assess their effectiveness compared to K-Means. Silhouette Score and Davies-Bouldin Score provide objective measures of clustering quality, enabling comparison across different algorithms and aiding in the selection of the most suitable clustering approach.
#
# **3.2.2.2.2. PO2 | PS2:: Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Comparison Models: DBSCAN | BIRCH | OPTICS - At Least One)**
#
# The computational efficiency of the comparison models (DBSCAN, BIRCH, OPTICS) was evaluated through time statistics and memory usage analysis. Understanding the computational requirements of alternative clustering algorithms is essential for practical implementation and scalability, particularly in resource-constrained environments. Time and memory statistics provide valuable insights into the computational trade-offs and performance considerations of each algorithm.
#
# **3.2.3.1. PO3 | PS3:: Cluster Analysis: Base Model (K-Means)**
#
# Cluster analysis was performed on the base model using K-Means clustering, aiming to identify distinct groups within the dataset based on similarity.
#
# **3.2.3.1.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
#
# Categorical variables underwent analysis using the Chi-Square Test of Independence to determine their significance in cluster formation. This statistical test assesses the relationship between categorical variables and cluster assignments, helping identify variables that contribute significantly to cluster differentiation.
#
# **3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
# Non-categorical variables were subjected to Analysis of Variance (ANOVA) to evaluate their contribution to cluster formation. ANOVA assesses the variability between groups, helping identify non-categorical variables that significantly differentiate clusters and influence cluster membership.
#
# **3.2.3.2. PO3 | PS3:: Cluster Analysis: Comparison Models (DBSCAN | BIRCH | OPTICS: At Least One)**
#
# Similar cluster analysis techniques were applied to the comparison models (DBSCAN, BIRCH, OPTICS) to assess their performance and variable significance.
#
# **3.2.3.2.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
#
# The Chi-Square Test of Independence was employed to analyze categorical variables in the comparison models, assessing their significance in cluster formation.
#
# **3.2.3.2.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
# ANOVA was applied to non-categorical variables in the comparison models to evaluate their role in cluster formation and significance in differentiating clusters.
#
# **4. Results | Observations**
#
# **4.1. Appropriate Number of Segments | Clusters: Base Model (K-Means) | Comparison Models (DBSCAN | BIRCH | OPTICS: At Least One)**
#
# The number of segments or clusters was determined for both the base model (K-Means) and the comparison models (DBSCAN, BIRCH, OPTICS), providing insights into the underlying structure of the data.
#
# **4.2. Cluster Size (Base Model | Comparison Models)**
#
# The size of each cluster was examined for both the base and comparison models to understand the distribution of data points across clusters.
#
# **4.3. Clustering Model Performance: Time & Memory Statistics [Base Model (K-Means) vs Comparison Models (DBSCAN | BIRCH | OPTICS: At Least One)]**
#
# Time statistics and memory usage were analyzed to compare the computational efficiency of the base model (K-Means) with the comparison models (DBSCAN, BIRCH, OPTICS), informing decisions regarding algorithm selection and resource allocation.
#
# **4.4. Cluster Analysis: Base Model (K-Means) | Comparison Models (DBSCAN | BIRCH | OPTICS: At Least One)**
#
# **4.4.1. Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
#
# The significance of both categorical and non-categorical variables in cluster formation was analyzed for both the base model (K-Means) and the comparison models (DBSCAN, BIRCH, OPTICS), providing insights into the factors driving cluster differentiation.
#
# **4.4.2. Non-Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
#
# The role of non-categorical variables in cluster formation was examined, distinguishing between contributing or significant var
#
# ### 5. Managerial Insights
#
# #### 5.1. Appropriate Model
# After evaluating both K-means and DBSCAN clustering algorithms, the K-means model emerges as the more suitable choice for segmentation. Its simplicity and clear delineation of clusters align well with managerial decision-making needs. While DBSCAN offers advantages such as handling noise points and irregular cluster shapes, its complexity may hinder interpretation. Therefore, K-means is preferred for its ease of understanding and implementation in managerial contexts, ensuring actionable insights from the segmentation analysis.
#
# #### 5.2. Appropriate Number of Segments | Clusters (Given the Appropriate Model)
# Through rigorous analysis, the appropriate number of segments or clusters is determined to be 5, based on the K-means algorithm. This conclusion is drawn from a thorough examination of clustering metrics and interpretability of the resulting clusters. The selection of 5 clusters strikes a balance between granularity and practicality, providing sufficient differentiation among consumer segments while avoiding excessive complexity that could impede managerial decision-making.
#
# #### 5.3. Identification of a ‘Niche’ Segment | Cluster (If Any)
# Within the segmented population, Cluster 3 emerges as a potential 'niche' segment warranting special attention. This cluster exhibits distinct characteristics compared to others, suggesting a subgroup with unique behaviors or preferences. Further exploration of Cluster 3 could unveil valuable insights into specific consumer needs or market opportunities that may have been overlooked. Recognizing and targeting niche segments like Cluster 3 can enhance marketing effectiveness and customer satisfaction by catering to specialized demands within the market landscape.
#
# #### 5.4. Segment | Cluster - (Heterogeneous) Identity | Nomenclature
# To facilitate clear communication and understanding, clusters are assigned descriptive names based on their demographic and behavioral profiles. The proposed nomenclature is as follows:
#
# - **Cluster 1: Moderate Income, Moderate Spending (MIMS)** - Represents individuals with balanced income and spending habits, indicative of a stable and moderate lifestyle.
# - **Cluster 2: High Income, High Spending (HIHS)** - Comprises affluent consumers who exhibit high levels of discretionary spending, reflecting a luxury-oriented lifestyle.
# - **Cluster 3: Niche Segment (NS)** - Represents a specialized subgroup with unique characteristics or preferences, requiring targeted marketing strategies for engagement.
# - **Cluster 4: Low Income, Low Spending (LILS)** - Encompasses individuals with limited financial resources and conservative spending patterns, necessitating cost-effective marketing approaches.
# - **Cluster 5: Moderate Income, High Spending (MIHS)** - Consists of consumers with moderate incomes but high discretionary spending, indicating a propensity for indulgence or luxury purchases within their means.
#
# These cluster identities provide a comprehensive understanding of the segmented population, enabling marketers to tailor strategies and offerings to each group's distinct needs and preferences effectively. Further analysis and refinement may be conducted to enhance the accuracy and relevance of these segmentations in driving managerial decision-making and market success.
# iables and non-contributing or non-significant variables across the base decision-making across various aspects of the business, enabling managers to better meet the needs and preferences of their target customers.

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# Load the CSV file into a pandas DataFrame
data = pd.read_csv(r"C:\Users\Shantanu\Downloads\Mall_Customers_Dataset.csv")

# %%
# first 5 rows in the dataframe
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Number of rows and columns
data.shape
# Out:
# (50000, 5)

# %%
# Information of the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              50000 non-null  int64
#  1   Gender                  50000 non-null  object
#  2   Age                     50000 non-null  int64
#  3   Annual Income (k$)      50000 non-null  int64
#  4   Spending Score (1-100)  50000 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 1.9+ MB

# %%
# Check missing values
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Choose the Annual Income Column & Spending Score column
X = data.iloc[:,[3,4]].values

print(X)
# Out:
# [[15 39]
#  [15 81]
#  [16  6]
#  ...
#  [53 92]
#  [92 76]
#  [57 64]]

# %%
# Choose the number of clusters

# %%
# Ignore FutureWarning about n_init
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Ignore UserWarning about the memory leak
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# find wcss value for different number of clusters
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters=i)
    km.fit(X)
    wcss.append(km.inertia_)

# %%
# Plot graph
sns.set()
plt.plot(range(1,11), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Optimum Number of Clusters = 5

# %%
# Traine k-Means Clustering Model
model = KMeans(n_clusters=5, init='k-means++', random_state=0)

# return a label for each data point based on their cluster
Y = model.fit_predict(X)

data["label"] = Y

data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  label
# 0           1    Male   19                  15                      39      3
# 1           2    Male   21                  15                      81      1
# 2           3  Female   20                  16                       6      3
# 3           4  Female   23                  16                      77      1
# 4           5  Female   31                  17                      40      3

# %%
# Visualizing all the Clusters
plt.figure(figsize=(10,10))
plt.scatter(X[Y==0,0], X[Y==0,1], s=50, c='green', label='Cluster 1')
plt.scatter(X[Y==1,0], X[Y==1,1], s=50, c='red', label='Cluster 2')
plt.scatter(X[Y==2,0], X[Y==2,1], s=50, c='yellow', label='Cluster 3')
plt.scatter(X[Y==3,0], X[Y==3,1], s=50, c='violet', label='Cluster 4')
plt.scatter(X[Y==4,0], X[Y==4,1], s=50, c='blue', label='Cluster 5')

plt.title('Customer Groups')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score')
plt.show()

# %%
features = data.iloc[:, 1:5]
features = features.drop(columns=['Gender'])
features.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Assuming 'features' is your dataframe containing the features

cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
cluster_labels = cluster.fit_predict(features)

plt.figure(figsize=(10, 7))

plt.scatter(features['Annual Income (k$)'], features['Spending Score (1-100)'], c=cluster_labels)

plt.xlabel("Annual Income", fontsize=15)
plt.ylabel("Spending Score", fontsize=15)

plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
# distribution plots

plt.figure(figsize = (20, 8))
plotnumber = 1

for col in ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']:
    if plotnumber <= 3:
        ax = plt.subplot(1, 3, plotnumber)
        sns.distplot(data[col])
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

centers = [[1, 1], [-1, -1], [1, -1]]  
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4, 
                            random_state=0)  # generate sample blobs

X = StandardScaler().fit_transform(X)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Assuming X is already defined and imported
db = DBSCAN(eps=0.3, min_samples=10).fit(X)

# We are calculating these for showcasing in diagram
# Creating an array of true and false as the same size as db.labels
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True  # Setting the indices of the core regions to True
labels = db.labels_  # Similar to the model.fit() method, it gives the labels of the clustered data

# %%
# Number of clusters in labels, ignoring noise if present.

# the label -1 is considered as noise by the DBSCAN algorithm
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0) 
n_noise_ = list(labels).count(-1)  # calculating the number of clusters

# %%
from sklearn import metrics  # Import the metrics module

# Assuming labels_true and labels are already defined and imported
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)

"""Homogeneity metric of a cluster labeling given a ground truth.
A clustering result satisfies homogeneity if all of its clusters
contain only data points which are members of a single class."""
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 18
# Homogeneity: 0.953

# %%
# Plot result
plt.figure(figsize = (5, 5))

# Black  is used for noise.
unique_labels = set(labels)  # identifying all the unique labels/clusters
colors = [plt.cm.Spectral(each)
          # creating the list of colours, generating the colourmap
          for each in np.linspace(0, 1, len(unique_labels))]  

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]
    class_member_mask = (labels == k)   # assigning class members for each class
    xy = X[class_member_mask & core_samples_mask] # creating the list of points for each class  
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),markeredgecolor='k', markersize=14)
    xy = X[class_member_mask & ~core_samples_mask] # creating the list of noise points   
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=14)
    
plt.title('Clustering using DBSCAN\n', fontsize = 15)
plt.show()

# %%
from scipy.stats import f_oneway
anova_result = data.groupby('Gender')['Spending Score (1-100)'].apply(list)
# Applying ANOVA test
f_statistic, p_value = f_oneway(*anova_result)

print("F-statistic:", f_statistic)
print("P-value:", p_value)
# Out:
# F-statistic: 4.752065979300834
# P-value: 0.029267789320102676

# %%
# 2.1.2. Data Size
data_size = data.memory_usage(deep=True).sum() / (1024 ** 2)  # Convert bytes to megabytes
print("2.1.2. Data Size:", data_size, "MB")

# 2.1.3. Data Shape
data_shape = data.shape
print("2.1.3. Data Shape (Dimension: Number of Variables | Number of Records):", data_shape)
# Out:
# 2.1.2. Data Size: 4.673025131225586 MB
# 2.1.3. Data Shape (Dimension: Number of Variables | Number of Records): (50000, 6)

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances
import numpy as np

df = pd.DataFrame(data)

# Step 2: Select attributes for clustering
attributes = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
X = df[attributes]

# Step 3: Preprocess data if necessary (e.g., scaling)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=2)  # Adjust parameters according to your data
labels = dbscan.fit_predict(X_scaled)

# Step 5: Calculate DBScore
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[dbscan.core_sample_indices_] = True

# Get the cluster points
clusters = [X_scaled[labels == i] for i in range(max(labels) + 1) if i != -1]

dbscore_total = 0
for i in range(len(clusters)):
    for j in range(i+1, len(clusters)):
        dbscore_total += euclidean_distances(clusters[i], clusters[j]).mean()

dbscore = dbscore_total / (len(clusters) * (len(clusters) - 1) / 2)

print("DBScore:", dbscore)
# Out:
# DBScore: 2.732482340620492

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

df = pd.DataFrame(data)

# Step 2: Select attributes for clustering
attributes = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
X = df[attributes]

# Step 3: Preprocess data if necessary (e.g., scaling)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=2)  # Adjust parameters according to your data
labels = dbscan.fit_predict(X_scaled)

# Step 5: Calculate Silhouette Score
sscore = silhouette_score(X_scaled, labels)

print("Silhouette Score:", sscore)
# Out:
# Silhouette Score: -0.03509469860977141

# %%
# 2.3. Descriptive Statistics

## 2.3.1. Descriptive Statistics: Categorical Variables or Features

### 2.3.1.1. Count | Frequency Statistics
categorical_variables = ['Gender']  # List of categorical variables
for var in categorical_variables:
    print(f"Count | Frequency Statistics for '{var}':")
    print(data[var].value_counts())
    print()

### 2.3.1.2. Proportion (Relative Frequency) Statistics
for var in categorical_variables:
    print(f"Proportion (Relative Frequency) Statistics for '{var}':")
    print(data[var].value_counts(normalize=True))
    print()

## 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features

### 2.3.2.1. Measures of Central Tendency
non_categorical_variables = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']  # List of non-categorical variables
print("Measures of Central Tendency:")
print(data[non_categorical_variables].mean())
print()

### 2.3.2.2. Measures of Dispersion
print("Measures of Dispersion:")
print(data[non_categorical_variables].std())
print()

### 2.3.2.3. Correlation Statistics (with Test of Correlation)
print("Correlation Statistics (with Test of Correlation):")
correlation_matrix = data[non_categorical_variables].corr()
print(correlation_matrix)
print()
# Out:
# Count | Frequency Statistics for 'Gender':
# Gender
# Male      25053
# Female    24947
# Name: count, dtype: int64
#
# Proportion (Relative Frequency) Statistics for 'Gender':
# Gender
# Male      0.50106
# Female    0.49894
# Name: proportion, dtype: float64
#
# Measures of Central Tendency:
# Age                       41.04518
# Annual Income (k$)        85.04590
# Spending Score (1-100)    50.62798
# dtype: float64
#
# Measures of Dispersion:
# Age                       11.296269
# Annual Income (k$)        26.292708
# Spending Score (1-100)    28.780626
# dtype: float64
#
# Correlation Statistics (with Test of Correlation):
#                              Age  Annual Income (k$)  Spending Score (1-100)
# Age                     1.000000           -0.001820                0.000838
# Annual Income (k$)     -0.001820            1.000000               -0.005781
# Spending Score (1-100)  0.000838           -0.005781                1.000000

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  label
# 0           1    Male   19                  15                      39      3
# 1           2    Male   21                  15                      81      1
# 2           3  Female   20                  16                       6      3
# 3           4  Female   23                  16                      77      1
# 4           5  Female   31                  17                      40      3

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt


# Convert categorical variables to numeric
data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})

# Separate features and target variable
X = data.drop(columns=['CustomerID', 'Spending Score (1-100)'])

# Impute missing values
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualize the data in the reduced dimensional space
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=data['Spending Score (1-100)'], cmap='viridis')
plt.title('PCA Visualization of Mall Customers Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Spending Score (1-100)')
plt.show()
